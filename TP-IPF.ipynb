# %%
import pandas as pd
import os
import librosa
import numpy as np
import scipy
import re


#Pickling
from six.moves import cPickle as pickle

#HTTP
import requests
import json

#
import collections
import math

import matplotlib.pyplot as plt
import matplotlib.style as ms
import librosa.display
import IPython.display as ipd
import seaborn
ms.use('seaborn-muted')
# %matplotlib inline

# %%
def get_pattern(text):
    text = json.dumps(text)
    url = 'http://192.168.2.101:7878/api/get_patt'
    data = dict(input_tweets = text)
    resp = requests.post(url=url, data=data)
    r = json.loads(resp.text)
    return map(lambda x: x['pattern'],r)
    
def get_deep_emotion(text):
    text = json.dumps(text)
    url = 'http://192.168.2.101:7878/api/get_emo'
    data = dict(input_tweets = text)
    resp = requests.post(url=url, data=data)
    r = json.loads(resp.text)
    return r



def clean_text(text, remove_actions = True):
    punct_str = '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~«»“…‘”'
    if(remove_actions):
        text = re.sub(r" ?\[[^)]+\]", "", text)
    for p in punct_str:
        text = text.replace(p,' ')
    text = re.sub(' +', ' ', text)
    return text.lower().strip()

# %%
# full = generate_IEMOCAP_df()
data = pd.read_csv('data/IEMOCAP_sentences.csv',index_col=0)
# data.head(3)
emotional_mapping = {'ang': 0, 'sad': 1, 'exc': 2, 'neu': 3,'fru': 4,'hap': 5,'fea': 6,'sur': 7,'dis': 8, 'xxx':9,'oth':10}
data['emotion_code'] = data['emotion'].map( emotional_mapping ).astype(int)
data = data[data.emotion_code < 6]

data['text'] = data['text'].apply(clean_text)
data.head(5)
# Out:
#                  index  start_time  end_time  \
# 0  Ses01F_impro01_F000      6.2901    8.2357
# 1  Ses01F_impro01_F001     10.0100   11.3925
# 2  Ses01F_impro01_F002     14.8872   18.0175
# 5  Ses01F_impro01_F005     27.4600   31.4900
# 6  Ses01F_impro01_F006     38.9650   43.5900
#
#                                                 text  \
# 0                                          excuse me
# 1                                               yeah
# 2                                 is there a problem
# 5           well what's the problem let me change it
# 6  what i'm getting an id this is why i'm here my...
#
#                                             wav_path  \
# 0  data/IEMOCAP_full_release/Session1/sentences/w...
# 1  data/IEMOCAP_full_release/Session1/sentences/w...
# 2  data/IEMOCAP_full_release/Session1/sentences/w...
# 5  data/IEMOCAP_full_release/Session1/sentences/w...
# 6  data/IEMOCAP_full_release/Session1/sentences/w...
#
#                                       alignment_path emotion  valence  \
# 0  data/IEMOCAP_full_release/Session1/sentences/F...     neu      2.5
# 1  data/IEMOCAP_full_release/Session1/sentences/F...     neu      2.5
# 2  data/IEMOCAP_full_release/Session1/sentences/F...     neu      2.5
# 5  data/IEMOCAP_full_release/Session1/sentences/F...     neu      2.5
# 6  data/IEMOCAP_full_release/Session1/sentences/F...     fru      2.0
#
#    arousal  dominance gender  emotion_code
# 0      2.5        2.5      F             3
# 1      2.5        2.5      F             3
# 2      2.5        2.5      F             3
# 5      3.5        2.0      F             3
# 6      3.5        3.5      F             4

# %%
# patterns = {'.+ .+ a', '.+ a', '.+ a .+', '.+ problem', '.+ there', 'a .+', 'is .+', 'is .+ a', 'is there .+','there .+','there a .+'}
# patterns = {}

def get_patterns_load(patterns):
    load = []
    for pat in patterns.iterrows():
        load = load + list(pat[1].dropna())
    return load

def extract_patterns(data,extract=False):
    if(extract):
        patterns = {}
        for index, row in data.iterrows():
            patterns[row['index']] = set(get_pattern([row['text']])[0].values())
            print('Extracted pattern from '+ row['index'] + ' index:'+ str(index))
            print('Size: ', len(patterns[row['index']]), 'Patterns size', len(patterns))
        try:
            print('Saving Pickle')
            with open('pickles/patterns/pattern.pickle','wb') as f:
                save = {
                    'patterns' : patterns
                }
                pickle.dump(save,f,pickle.HIGHEST_PROTOCOL)
                print('Successfully saved in pattern.pickle')
                return patterns
        except Exception as e:
            print('Unable to save data to pickle', e)
            print('Patterns probably not saved.')
            return patterns
    else:
        try:
            with open('pickles/patterns/pattern.pickle','rb') as f:
                save = pickle.load(f)
                patterns = save['patterns']
                del save
                return patterns
        except Exception as e:
            print('Error loading base datasets pickle: ', e)
        
        
patterns = extract_patterns(data)  
patterns_df = pd.DataFrame.from_dict(patterns, orient='index')

# %%
# ang_index = data[data.emotion_code == 0]['index']
# sad_index = data[data.emotion_code == 1]['index']
# exc_index = data[data.emotion_code == 2]['index']
# neu_index = data[data.emotion_code == 3]['index']
# fru_index = data[data.emotion_code == 4]['index']
# hap_index = data[data.emotion_code == 5]['index']
# ang_patterns = patterns_df.loc[list(ang_index)]
# sad_patterns = patterns_df.loc[list(sad_index)]
# exc_patterns = patterns_df.loc[list(exc_index)]
# neu_patterns = patterns_df.loc[list(neu_index)]
# fru_patterns = patterns_df.loc[list(fru_index)]
# hap_patterns = patterns_df.loc[list(hap_index)]

# ang_load = get_patterns_load(ang_patterns)
# sad_load = get_patterns_load(sad_patterns)
# exc_load = get_patterns_load(exc_patterns)
# neu_load = get_patterns_load(neu_patterns)
# fru_load = get_patterns_load(fru_patterns)
# hap_load = get_patterns_load(hap_patterns)
# all_patterns = get_patterns_load(patterns_df)

# emotions_load ={'ang':ang_load,'sad':sad_load, 'exc':exc_load,'neu':neu_load,'fru':fru_load, 'hap': hap_load }

# %%
def pf_ief(pattern,emotions_load,emotions_counter,emotion):
    pf = 0.0
    counter = emotions_counter[emotion]
    for patt in emotions_load[emotion]:
        pf += counter[patt]
    pf += 1
    pf = math.log((pf) / (counter[pattern] + 1),10)
    ief = math.log((counter[pattern] + 1) / (sum_freq(pattern,emotions_counter) + 1),10)
    return pf * ief
    
def sum_freq(pattern,emotions_counter):
    res = 0.0
    for emotion in emotions_counter:
        res += emotions_counter[emotion][pattern]
    return res

pf_ief(pattern,emotions_load,emotions_counter,'ang')

def build_pf_ief_model(data):
    data_patterns = extract_patterns(data)  
    patterns_df = pd.DataFrame.from_dict(data_patterns, orient='index')
    emo_list = list(data.emotion.unique())
    emotions_load = {}
    emotions_counter = {}
    for emotion in emo_list:
        index = data[data.emotion == emotion]['index']
        emo_patterns = patterns_df.loc[list(ang_index)]
        emotions_load[emotion] = get_patterns_load(emo_patterns)
        emotions_counter[emotion] = collections.Counter(emotions_load[emotion])
    df = {}
    all_patterns = get_patterns_load(patterns_df)
    for pattern in all_patterns:
        emo_scores = {}
        for emotion in emo_list:
            emo_scores[emotion] = pf_ief(pattern,emotions_load,emotions_counter,emotion)
        df[pattern] = emo_scores
    return df

# %%
em_df = build_pf_ief_model(data)

# %%
em_df

# %%
emotion = 'ang'
pattern = ang_load[0]
pattern
counter = collections.Counter(ang_load)

# %%
result = 0
counter = collections.Counter(emotions_load[emotion])
for patt in emotions_load[emotion]:
    result += counter[patt]

# %%
# Out:
# 43
# 58
# 52
# 120
# 24
# 65
# ('test', Counter({u'you .+': 416, u'.+ you': 395, u'you .+ .+': 394, u'.+ you .+': 369, u'i .+': 367, u'.+ .+ you': 356, u'.+ i': 306, u'.+ i .+': 304, u'to .+': 292, u'.+ to': 287, u'.+ to .+': 285, u'.+ .+ to': 283, u'.+ .+ i': 281, u'to .+ .+': 275, u'a .+': 219, u'.+ a .+': 218, u'.+ a': 218, u'the .+': 216, u'.+ the': 214, u'.+ the .+': 213, u'and .+': 208, u'.+ and': 201, u'.+ .+ a': 200, u'.+ and .+': 199, u'the .+ .+': 198, u'.+ .+ and': 198, u'a .+ .+': 198, u'.+ it': 169, u'.+ me': 168, u'.+ .+ me': 164, u'.+ that': 161, u'what .+': 157, u'.+ .+ that': 156, u'it .+': 147, u'.+ it .+': 144, u'.+ is': 143, u'is .+': 138, u'me .+': 136, u'.+ is .+': 136, u'.+ me .+': 135, u'that .+': 131, u'of .+': 128, u'.+ that .+': 128, u'.+ of': 127, u'.+ of .+': 127, u'.+ have': 123, u'.+ have .+': 122, u'have .+': 122, u'me .+ .+': 120, u'.+ .+ of': 120, u'.+ what': 117, u'do .+': 114, u'.+ .+ is': 114, u'.+ not': 111, u'.+ do': 110, u'in .+': 109, u'.+ do .+': 109, u'not .+': 109, u'.+ this': 108, u'.+ in': 108, u'.+ in .+': 108, u'.+ .+ in': 103, u'.+ not .+': 101, u'.+ like': 100, u'this .+': 99, u'like .+': 96, u'.+ like .+': 94, u'for .+': 93, u'just .+': 91, u'.+ just': 89, u'.+ just .+': 87, u'.+ for': 84, u'.+ .+ for': 84, u'on .+': 83, u'.+ for .+': 83, u'.+ this .+': 83, u'.+ on': 83, u'.+ on .+': 82, u'my .+': 81, u'.+ .+ on': 81, u'.+ my': 80, u'.+ my .+': 79, u'going .+': 78, u'.+ going': 76, u'.+ .+ my': 76, u'no .+': 76, u'.+ know': 72, u'know .+': 71, u'.+ all': 70, u'if .+': 67, u'my .+ .+': 67, u'.+ if': 66, u'all .+': 64, u'.+ with': 64, u'with .+': 64, u'.+ all .+': 64, u'.+ want': 64, u'.+ with .+': 63, u'are .+': 63, u'.+ .+ with': 62, u'do you .+': 62, u'.+ your .+': 61, u'.+ your': 61, u'your .+': 61, u'want .+': 60, u'are .+ .+': 58, u'oh .+': 58, u'oh .+ .+': 58, u'.+ do you': 57, u'.+ be': 57, u'.+ .+ if': 56, u'be .+': 56, u'.+ mean': 56, u'.+ be .+': 55, u'.+ go': 55, u'well .+': 55, u'why .+': 55, u'.+ at': 55, u'.+ are': 54, u'.+ up': 54, u'at .+': 54, u'.+ at .+': 54, u'mean .+': 53, u'go .+': 53, u'.+ never': 53, u'about .+': 53, u'because .+': 53, u'.+ are .+': 53, u'.+ go .+': 53, u'.+ never .+': 52, u'never .+': 52, u'.+ about': 52, u'but .+': 51, u'.+ about .+': 51, u'.+ no': 50, u'.+ think': 50, u'very .+': 49, u'.+ get .+': 49, u'.+ get': 49, u'get .+': 49, u'you know .+': 48, u'.+ here': 48, u'.+ going to': 48, u'going to .+': 48, u'think .+': 48, u'we .+': 48, u'i .+ to': 47, u'.+ no .+': 47, u'see .+': 46, u'.+ see': 46, u'.+ back': 46, u'they .+': 44, u'.+ again': 44, u'i .+ you': 44, u'.+ out': 43, u'.+ but': 43, u'.+ but .+': 42, u'.+ why': 42, u'back .+': 42, u'you .+ me': 42, u'.+ business': 42, u'little .+': 41, u'.+ little': 40, u'so .+': 39, u'out .+': 39, u'.+ out .+': 39, u'.+ you know': 39, u'can .+': 38, u'.+ up .+': 37, u'got .+': 37, u'.+ we': 37, u'this is .+': 37, u'.+ because': 37, u'.+ got': 37, u'up .+': 37, u'.+ can': 37, u'.+ hate': 36, u'.+ hell': 36, u'i hate .+': 36, u'and i .+': 36, u'hell .+': 36, u'.+ had': 36, u'hate .+': 36, u'.+ so': 35, u'again .+': 35, u'.+ they': 35, u'had .+': 35, u'.+ and i': 35, u'.+ him': 34, u'.+ right': 34, u'.+ i hate': 34, u'look .+': 34, u'god .+': 34, u'i mean .+': 34, u'.+ am': 34, u'.+ very': 34, u'three .+': 34, u'here .+': 34, u'be .+ .+': 33, u'.+ three': 33, u'.+ god': 33, u'right .+': 33, u'.+ so .+': 33, u'.+ right .+': 31, u'.+ want to': 31, u'.+ now': 31, u'.+ then': 31, u'turn .+': 31, u'then .+': 31, u'.+ did': 31, u'did .+': 31, u'.+ i mean': 31, u'.+ god .+': 31, u'want to .+': 29, u'.+ years': 29, u'.+ good': 29, u'good .+': 29, u'i .+ i': 29, u'am .+': 29, u'what the .+': 28, u'.+ been': 28, u'business .+': 28, u'yes .+': 28, u'been .+': 28, u'she .+': 28, u'.+ long': 27, u'.+ look': 27, u'you have .+': 27, u'years .+': 27, u'.+ the hell': 27, u'.+ too': 27, u'long .+': 27, u'the hell .+': 27, u'really .+': 27, u'people .+': 26, u'the .+ is': 26, u'i want .+': 26, u'would .+': 26, u'there .+': 26, u'.+ time': 26, u ...
# 0
# 0.0

# %%
collections.Counter(emotions_load[emotion])
# Out:
# Counter({u'not .+ up': 1,
#          u'you my .+': 1,
#          u'.+ for you': 12,
#          u'.+ do you': 57,
#          u'was .+ like': 1,
#          u'with .+ in': 1,
#          u'.+ of what': 3,
#          u'done with .+': 1,
#          u'a week .+': 1,
#          u'.+ can not': 1,
#          u'.+ makes you': 1,
#          u'.+ be': 57,
#          u'can .+ a': 2,
#          u'is for .+': 4,
#          u'the .+ this': 3,
#          u'to make .+': 7,
#          u'.+ kids': 8,
#          u'.+ turn': 11,
#          u'.+ deal': 7,
#          u'do .+ have': 7,
#          u'busy .+': 1,
#          u'.+ by': 5,
#          u'.+ last week': 3,
#          u'is this .+': 7,
#          u'they were .+': 1,
#          u'.+ husband': 1,
#          u'.+ of her': 2,
#          u'.+ me': 168,
#          u'do .+ it': 1,
#          u'single .+': 3,
#          u'.+ stop .+': 11,
#          u'oh oh .+': 2,
#          u'to .+ you': 18,
#          u'minutes .+': 2,
#          u'.+ from .+': 15,
#          u'.+ right .+': 31,
#          u'stand .+': 7,
#          u'go away .+': 8,
#          u'kids .+': 6,
#          u'.+ my': 80,
#          u'from .+': 17,
#          u'.+ in my': 9,
#          u'thank .+': 10,
#          u'.+ long': 27,
#          u'.+ at the': 9,
#          u'room and .+': 4,
#          u'out there .+': 1,
#          u'is to .+': 3,
#          u'it .+': 147,
#          u'we can .+': 3,
#          u'mean .+': 53,
#          u'you think .+': 14,
#          u'.+ to help': 1,
#          u'far too .+': 7,
#          u'.+ or a': 1,
#          u'even .+ to': 1,
#          u'clearly .+': 1,
#          u'.+ over': 22,
#          u'here and .+': 5,
#          u'after the .+': 1,
#          u'.+ every time': 4,
#          u'.+ going to': 48,
#          u'it by .+': 1,
#          u'.+ up .+': 37,
#          u'.+ also': 3,
#          u'.+ wants': 1,
#          u'much to .+': 1,
#          u'.+ never .+': 52,
#          u'her .+': 21,
#          u'.+ coffee': 1,
#          u'.+ possible': 2,
#          u'my .+ stuff': 1,
#          u'getting .+': 7,
#          u'you are .+': 23,
#          u'.+ my hands': 5,
#          u'.+ expect': 8,
#          u'have .+ you': 7,
#          u'people .+': 26,
#          u'.+ they have': 7,
#          u'why why .+': 1,
#          u'.+ not to': 3,
#          u'hate you .+': 14,
#          u'all day .+': 9,
#          u'.+ is .+': 136,
#          u'if i .+': 17,
#          u'.+ after .+': 13,
#          u'of my .+': 3,
#          u'just a .+': 2,
#          u'to keep .+': 1,
#          u'little .+ that': 1,
#          u'all you .+': 3,
#          u'those .+': 2,
#          u'.+ business': 42,
#          u'.+ away': 20,
#          u'the .+ with': 10,
#          u'.+ something': 13,
#          u'.+ and the': 8,
#          u'road .+': 3,
#          u'.+ are so': 1,
#          u'.+ will do': 2,
#          u'like .+ to': 1,
#          u'sign .+': 4,
#          u'window .+': 1,
#          u'to .+ with': 12,
#          u'is going .+': 9,
#          u'the .+ now': 1,
#          u'a .+ good': 3,
#          u'is .+ about': 2,
#          u'.+ you will': 1,
#          u'of a .+': 4,
#          u'.+ shows': 2,
#          u'.+ feel': 11,
#          u'is .+ this': 5,
#          u'a man .+': 1,
#          u'at .+ like': 1,
#          u'can .+ you': 1,
#          u'.+ he is': 3,
#          u'our .+': 8,
#          u'.+ like': 100,
#          u'.+ my stuff': 3,
#          u'want to .+': 29,
#          u'never ever .+': 1,
#          u'on .+ again': 5,
#          u'i know .+': 9,
#          u'go .+ in': 2,
#          u'please just .+': 2,
#          u'who are .+': 1,
#          u'like .+ a': 2,
#          u'nothing .+': 8,
#          u'.+ a little': 12,
#          u'come .+': 16,
#          u'for some .+': 2,
#          u'give you .+': 2,
#          u'know the .+': 1,
#          u'.+ less': 5,
#          u'all .+': 64,
#          u'.+ with .+': 63,
#          u'told .+': 9,
#          u'.+ looking for': 2,
#          u'.+ i can': 11,
#          u'sure .+': 5,
#          u'he .+ her': 7,
#          u'go through .+': 1,
#          u'keeps .+': 1,
#          u'is it .+': 2,
#          u'take .+': 11,
#          u'drunk .+': 8,
#          u'went .+': 6,
#          u'.+ wow': 3,
#          u'that .+': 131,
#          u'people .+ in': 1,
#          u'.+ shopping': 1,
#          u'.+ downstairs': 6,
#          u'the one .+': 2,
#          u'.+ sent': 1,
#          u'he is .+': 3,
#          u'be in .+': 1,
#          u'.+ studio': 3,
#          u'.+ you get': 7,
#          u'.+ to do': 18,
#          u'the phone .+': 2,
#          u'your own .+': 10,
#          u'want my .+': 1,
#          u'.+ have': 123,
#          u'.+ making': 1,
#          u'.+ all this': 3,
#          u'.+ in this': 5,
#          u'then .+ you': 2,
#          u'fun .+': 1,
#          u'.+ things to': 1,
#          u'.+ now i': 2,
#          u'the same .+': 2,
#          u'bored .+': 3,
#          u'.+ i do': 5,
#          u'san .+': 2,
#          u'just .+ me': 4,
#          u'very .+': 49,
#          u'makes you .+': 1,
#          u'not to .+': 4,
#          u'much .+': 19,
#          u'.+ talent': 6,
#          u'.+ days': 1,
#          u'.+ you always': 10,
#          u'no .+ in': 3,
#          u'.+ going': 76,
#          u'come home .+': 1,
#          u'.+ me out': 1,
#          u'.+ since': 6,
#          u'fit .+': 7,
#          u'getting my .+': 2,
#          u'.+ keeps': 1,
#          u'this .+': 99,
#          u'back to .+': 4,
#          u'.+ go to': 4,
#          u'.+ for one': 1,
#          u'.+ car': 1,
#          u'gonna .+ it': 1,
#          u'.+ the moment': 4,
#          u'women .+': 1,
#          u'it that .+': 1,
#          u'.+ my house': 2,
#          u'said .+': 12,
#          u'over .+': 21,
#          u'.+ this whole': 3,
#          u'.+ told': 9,
#          u'about a .+': 5,
#          u'gonna be .+': 1,
#          u'.+ about what': 3,
#          u'gave me .+': 1,
#          u'you see .+': 4,
#          u'.+ you': 395,
#          u'.+ movie': 1,
#          u'.+ why did': 2,
#          u'in .+ is': 1,
#          u'my phone .+': 3,
#          u'.+ girl': 21,
#          u'wind .+': 2,
#          u'and .+': 208,
#          u'.+ was going': 1,
#          u'.+ single': 3,
#          u'.+ there is': 2,
#          u'.+ goes': 5,
#          u'open .+': 3,
#          u'.+ new': 14,
#          u'bloody .+': 1,
#          u'.+ look like': 5,
#          u'.+ blue': 4,
#          u'looking for .+': 2,
#          u'o .+': 1,
#          u'but .+ that': 2,
#          u'.+ are': 54,
#          u'.+ away in': 2,
#          u'go .+': 53,
#          u'and .+ to': 2,
#          u'to believe .+': 5,
#          u'but it .+': 4,
#          u'.+ where': 14,
#          u'like that .+': 7,
#          u'name is .+': 1,
#          u'.+ nights': 1,
#          u'drive .+': 2,
#          u'see you .+': 13,
#          u'.+ look': 27,
#          u'helping .+': 2,
#          u'am .+ the': 1,
#          u'at .+ i': 4,
#          u'.+ your name': 2,
#          u'they .+': 44,
#          u'because it .+': 1,
#          u'far .+': 7,
#          u'.+ like you': 4,
#          u'soon .+': 1,
#          u'that it .+': 1,
#          u'man .+': 2,
#          u'.+ it and': 3,
#          u'me .+ just': 1,
#          u'.+ so': 35,
#          u'the .+ but': 5,
#          u'.+ make': 14,
#          u'.+ gave': 1,
#          u'get to .+': 2,
#          u'.+ to find': 3,
#          u'.+ please': 7,
#          u'such .+': 13,
#          u'just like .+': 4,
#          u'yes i .+': 23,
#          u'.+ eye': 1,
#          u'.+ me a': 10,
#          u'the .+ you': 5,
#          u'more .+ in': 1,
#          u'day i .+': 2,
#          u'.+ me i': 4,
#          u'like a .+': 9,
#          u'peter .+': 8,
#          u'then they .+': 4,
#          u'.+ our .+': 8,
#          u'.+ me to': 9,
#          u'getting to .+': 1,
#          u'.+ straight': 2,
#          u'real .+': 1,
#          u'.+ would be': 4,
#          u'makes me .+': 1,
#          u'.+ what': 117,
#          u'the .+ when': 1,
#          u'.+ where are': 4,
#          u'.+ through the': 1,
#          u'.+ by .+': 5,
#          u'.+ of me': 9,
#          u'half .+': 7,
#          u'.+ little': 40,
#          u'was .+': 20,
#          u'person .+': 2,
#          u'.+ is full': 3,
#          u'i got .+': 13,
#          u'home .+': 4,
#          u'.+ die in': 8,
#          u'give me .+': 14,
#          u'.+ gave me': 1,
#          u'i went .+': 1,
#          u'to .+ them': 3,
#          u'kate .+': 1,
#          u'will not .+': 2,
#          u'call me .+': 1,
#          u'a .+ to': 5,
#          u'like .+ on': 1,
#          u'.+ child': 16,
#          u'.+ hear': 14,
#          u'with all .+': 1,
#          u'and .+ her': 1,
#          u'to .+ his': 3,
#          u'simple .+': 2,
#          u'went to .+': 2,
#          u'.+ whole': 16,
#          u'believe .+': 12,
#          u'.+ head': 7,
#          u'.+ on you': 8,
#          u'.+ your .+': 61,
#          u'joe .+': 12,
#          u'.+ problem': 4,
#          u'to .+ up': 10,
#          u'and .+ they': 5,
#          u'.+ .+ that': 156,
#          u'.+ home to': 1,
#          u'you never .+': 9,
#          u'.+ it .+': 144,
#          u'when she .+': 2,
#          u'and .+ them': 2,
#          u'too .+': 25,
#          u'for .+': 93,
#          u'.+ i have': 20,
#          u'how .+ the': 1,
#          u'i .+ and': 7,
#          u'be all .+': 1,
#          u'i .+ my': 7,
#          u'good .+ and': 1,
#          u'you that .+': 1,
#          u'i .+ some': 3,
#          u'.+ want to': 31,
#          u'they .+ or': 1,
#          u'week .+': 5,
#          u'kind of .+': 2,
#          u'.+ again': 44,
#          u'.+ clear': 1,
#          u'.+ me for': 1,
#          u'.+ are in': 1,
#          u'.+ giving': 2,
#          u'.+ will': 20,
#          u'hours .+': 3,
#          u'.+ be .+': 55,
#          u'.+ is in': 2,
#          u'.+ like a': 9,
#          u'.+ and his': 6,
#          u'you a .+': 11,
#          u'.+ day': 11,
#          u'whole .+': 16,
#          u'now .+ in': 1,
#          u'.+ dad': 8,
#          u'just .+ you': 9,
#          u'down and .+': 1,
#          u'to .+ to': 11,
#          u'.+ is it': 1,
#          u'.+ there': 22,
#          u'a .+ and': 5,
#          u'a .+ back': 1,
#          u'just .+ with': 1,
#          u'to the .+': 15,
#          u'.+ said': 13,
#          u'would be .+': 3,
#          u'everything .+': 9,
#          u'.+ whatever': 4,
#          u'think .+ is': 4,
#          u'in .+': 109,
#          u'blood .+': 1,
#          u'.+ to go': 15,
#          u'what .+ just': 1,
#          u'put .+': 6,
#          u'and .+ and': 10,
#          u'.+ every day': 1,
#          u'will never .+': 2,
#          u'to like .+': 2,
#          u'.+ would make': 1,
#          u'to .+ like': 17,
#          u'.+ to the': 15,
#          u'.+ would have': 4,
#          u'.+ wedding': 2,
#          u'they .+ me': 3,
#          u'.+ has a': 1,
#          u'.+ write': 1,
#          u'.+ and she': 2,
#          u'you know .+': 48,
#          u'two .+': 15,
#          u'bit .+': 8,
#          u'check .+': 2,
#          u'.+ walking': 2,
#          u'she is .+': 3,
#          u'are .+ .+': 58,
#          u'vampire .+': 8,
#          u'.+ we can': 2,
#          u'and .+ one': 1,
#          u'.+ i hope': 15,
#          u'.+ die': 12,
#          u'my .+ too': 2,
#          u'.+ broke': 2,
#          u'.+ but the': 1,
#          u'a good .+': 17,
#          u'right to .+': 3,
#          u'are you .+': 21,
#          u'.+ have a': 18,
#          u'be so .+': 7,
#          u'on your .+': 8,
#          u'is .+ of': 3,
#          u'of .+ for': 1,
#          u'and .+ it': 2,
#          u'is .+ on': 5,
#          u'and .+ is': 3,
#          u'and .+ in': 2,
#          u'pass .+': 5,
#          u'or a .+': 1,
#          u'been .+ all': 1,
#          u'.+ at and': 1,
#          u'build .+': 2,
#          u'.+ came in': 1,
#          u'going to .+': 48,
#          u'.+ everything that': 2,
#          u'what .+ you': 24,
#          u'.+ some': 19,
#          u'a little .+': 12,
#          u'all of .+': 7,
#          u'and there .+': 1,
#          u'.+ not in': 7,
#          u'could get .+': 5,
#          u'.+ what a': 1,
#          u'.+ to what': 1,
#          u'.+ him': 34,
#          u'.+ have the': 2,
#          u'.+ what i': 15,
#          u'up on .+': 1,
#          u'get .+ to': 3,
#          u'.+ somehow': 2,
#          u'where my .+': 1,
#          u'.+ will die': 1,
#          u'a .+ you': 8,
#          u'or .+': 12,
#          u'.+ with': 64,
#          u'.+ letter': 1,
#          u'one .+': 15,
#          u'to call .+': 5,
#          u'through .+': 7,
#          u'my eyes .+': 4,
#          u'in .+ for': 1,
#          u'.+ right': 34,
#          u'.+ form': 7,
#          u'came to .+': 1,
#          u'calling me .+': 1,
#          u'too .+ to': 1,
#          u'.+ from': 15,
#          u'to come .+': 2,
#          u'.+ .+ me': 164,
#          u'got into .+': 3,
#          u'.+ tickets': 2,
#          u'.+ somewhere': 5,
#          u'.+ is going': 9,
#          u'took .+': 3,
#          u'one is .+': 1,
#          u'the .+ again': 1,
#          u'means .+': 1,
#          u'.+ .+ my': 76,
#          u'.+ any of': 1,
#          u'.+ after the': 1,
#          u'.+ give': 18,
#          u'.+ you a': 11,
#          u'with you .+': 8,
#          u'.+ finally': 7,
#          u'buy .+': 1,
#          u'easy .+': 1,
#          u'.+ kid': 1,
#          u'have .+ of': 1,
#          u'.+ face': 3,
#          u'.+ light': 1,
#          u'before .+': 10,
#          u'have .+ on': 1,
#          u'.+ we': 37,
#          u'.+ water': 1,
#          u'huge .+': 1,
#          u'.+ ones': 1,
#          u'.+ stuff': 9,
#          u'.+ above': 14,
#          u'.+ about a': 5,
#          u'.+ and no': 3,
#          u'.+ she': 24,
#          u'.+ men': 3,
#          u'with my .+': 8,
#          u'.+ just .+': 87,
#          u'.+ thing i': 2,
#          u'a .+ will': 1,
#          u'.+ i will': 9,
#          u'.+ .+ i': 281,
#          u'.+ that movie': 1,
#          u'chris .+': 9,
#          u'we have .+': 4,
#          u'.+ shut': 16,
#          u'.+ and my': 4,
#          u'.+ .+ a': 200,
#          u'.+ and not': 1,
#          u'the .+ and': 12,
#          u'do .+': 114,
#          u'no .+ no': 5,
#          u'does .+': 9,
#          u'to turn .+': 3,
#          u'every .+ i': 1,
#          u'can you .+': 6,
#          u'you marry .+': 4,
#          u'the .+ one': 2,
#          u'.+ but she': 1,
#          u'go get .+': 3,
#          u'was .+ but': 1,
#          u'me right .+': 1,
#          u'.+ believe': 12,
#          u'enough .+': 13,
#          u'control .+': 8,
#          u'not .+ this': 1,
#          u'has .+ of': 1,
#          u'.+ things': 10,
#          u'.+ getting out': 1,
#          u'shit .+': 2,
#          u'do that .+': 4,
#          u'.+ happy': 2,
#          u'all these .+': 2,
#          u'has .+': 9,
#          u'.+ wants to': 1,
#          u'i have .+': 21,
#          u'.+ event': 2,
#          u'hour .+': 7,
#          u'.+ to arrive': 1,
#          u'.+ is to': 3,
#          u'i had .+': 14,
#          u'end .+': 11,
#          u'me the .+': 3,
#          u'.+ i keep': 2,
#          u'stupid .+': 5,
#          u'.+ know what': 16,
#          u'.+ this': 108,
#          u'goes to .+': 5,
#          u'stay .+': 4,
#          u'.+ do': 110,
#          u'with .+': 64,
#          u'.+ try': 9,
#          u'.+ you want': 16,
#          u'.+ am i': 5,
#          u'.+ into the': 1,
#          u'baby .+': 4,
#          u'.+ from one': 1,
#          u'think i .+': 14,
#          u'flat .+': 1,
#          u'.+ me your': 2,
#          u'bag .+': 13,
#          u'.+ being': 9,
#          u'.+ the next': 4,
#          u'.+ that was': 1,
#          u'.+ much': 20,
#          u'your .+ with': 1,
#          u'too bad .+': 1,
#          u'go and .+': 3,
#          u'.+ check': 6,
#          u'.+ back to': 4,
#          u'why does .+': 2,
#          u'any more .+': 2,
#          u'.+ are you': 16,
#          u'.+ i really': 3,
#          u'we .+ for': 6,
#          u'.+ yourself': 18,
#          u'.+ needs to': 2,
#          u'.+ the way': 3,
#          u'so much .+': 4,
#          u'once .+': 2,
#          u'hear the .+': 2,
#          u'.+ if the': 1,
#          u'.+ about this': 7,
#          u'the .+ .+': 198,
#          u'.+ of it': 7,
#          u'with me .+': 4,
#          u'your .+ i': 3,
#          u'.+ because': 37,
#          u'snap .+': 9,
#          u'without .+': 2,
#          u'themselves .+': 2,
#          u'not my .+': 1,
#          u'more than .+': 7,
#          u'is no .+': 7,
#          u'extreme .+': 1,
#          u'am .+ and': 3,
#          u'i hope .+': 15,
#          u'not even .+': 1,
#          u'.+ you really': 2,
#          u'i would .+': 7,
#          u'me .+ for': 2,
#          u'me that .+': 10,
#          u'and this .+': 2,
#          u'.+ moments': 2,
#          u'.+ it i': 9,
#          u'in all .+': 1,
#          u'to .+ .+': 275,
#          u'you .+': 416,
#          u'.+ week': 5,
#          u'of .+ of': 1,
#          u'face .+': 3,
#          u'.+ might': 6,
#          u'sitting here .+': 2,
#          u'of .+ or': 2,
#          u'.+ in front': 1,
#          u'me .+ than': 1,
#          u'to write .+': 1,
#          u'so .+ and': 1,
#          u'.+ hope': 19,
#          u'to .+ something': 2,
#          u'kid .+': 1,
#          u'a .+ up': 1,
#          u'me .+ .+': 120,
#          u'i .+ what': 10,
#          u'.+ in the': 24,
#          u'.+ it out': 2,
#          u'.+ i got': 13,
#          u'nobody .+': 15,
#          u'challenge .+': 2,
#          u'and make .+': 1,
#          u'again .+': 35,
#          u'not .+ you': 1,
#          u'.+ open': 4,
#          u'to .+ out': 5,
#          u'for me .+': 2,
#          u'but to .+': 1,
#          u'gone .+': 2,
#          u'it .+ my': 1,
#          u'will .+ the': 1,
#          u'sorry .+': 3,
#          u'listening to .+': 10,
#          u'wake up .+': 2,
#          u'see my .+': 1,
#          u'steal .+': 1,
#          u'.+ why is': 3,
#          u'show .+': 8,
#          u'.+ to another': 3,
#          u'.+ up and': 5,
#          u'it .+ me': 1,
#          u'he was .+': 3,
#          u'a .+ man': 1,
#          u'for .+ the': 2,
#          u'.+ on here': 6,
#          u'out like .+': 1,
#          u'air .+': 1,
#          u'.+ in their': 1,
#          u'the .+ right': 1,
#          u'.+ on this': 4,
#          u'up .+ i': 2,
#          u'of .+': 128,
#          u'.+ before i': 4,
#          u'month .+': 4,
#          u'know that .+': 9,
#          u'.+ have to': 19,
#          u'the .+ it': 1,
#          u'four .+': 11,
#          u'my whole .+': 6,
#          u'.+ out with': 2,
#          u'music .+': 1,
#          u'the .+ is': 26,
#          u'um .+': 2,
#          u'.+ imagine': 2,
#          u'.+ came back': 4,
#          u'being .+': 8,
#          u'the .+ in': 6,
#          u'.+ will always': 1,
#          u'total .+': 1,
#          u'a .+ time': 6,
#          u'i see .+': 1,
#          u'people are .+': 1,
#          u'from .+ i': 1,
#          u'had a .+': 10,
#          u'before i .+': 4,
#          u'of .+ to': 11,
#          u'.+ i like': 7,
#          u'be .+ when': 1,
#          u'make the .+': 1,
#          u'.+ hate': 36,
#          u'be .+ next': 1,
#          u'get my .+': 3,
#          u'to do .+': 16,
#          u'never really .+': 1,
#          u'.+ these': 9,
#          u'all .+ for': 1,
#          u'you .+ to': 24,
#          u'boss .+': 1,
#          u'.+ shit': 2,
#          u'she just .+': 1,
#          u'.+ here and': 5,
#          u'.+ riding': 2,
#          u'who is .+': 1,
#          u'.+ get to': 2,
#          u'what the .+': 28,
#          u'at .+ but': 4,
#          u'.+ to have': 8,
#          u'got .+': 37,
#          u'.+ full': 3,
#          u'see .+': 46,
#          u'.+ to your': 8,
#          u'sounds like .+': 1,
#          u'are a .+': 6,
#          u'.+ room': 6,
#          u'.+ come home': 1,
#          u'.+ flight': 3,
#          u'my .+ like': 2,
#          u'.+ as you': 2,
#          u'take a .+': 1,
#          u'in .+ on': 1,
#          u'.+ cream': 2,
#          u'that .+ me': 6,
#          u'.+ their .+': 5,
#          u'become .+': 2,
#          u'finish .+': 1,
#          u'or .+ about': 1,
#          u'heard .+': 1,
#          u'my .+': 81,
#          u'to start .+': 2,
#          u'they never .+': 2,
#          u'me like .+': 2,
#          u'.+ website': 1,
#          u'.+ time to': 1,
#          u'if you .+': 24,
#          u'.+ on a': 2,
#          u'.+ trouble': 4,
#          u'.+ when .+': 21,
#          u'driving me .+': 8,
#          u'we .+ in': 1,
#          u'i .+ not': 8,
#          u'girl .+': 15,
#          u'.+ someone else': 2,
#          u'and .+ out': 1,
#          u'happen .+': 14,
#          u'though .+': 1,
#          u'they have .+': 7,
#          u'.+ to check': 1,
#          u'they get .+': 2,
#          u'i want .+': 26,
#          u'my window .+': 1,
#          u'body .+': 3,
#          u'this .+ i': 1,
#          u'the real .+': 1,
#          u'such a .+': 6,
#          u'.+ out of': 10,
#          u'my life .+': 1,
#          u'got that .+': 4,
#          u'is the .+': 19,
#          u'you .+ about': 1,
#          u'.+ people have': 2,
#          u'you look .+': 2,
#          u'.+ like .+': 94,
#          u'.+ be at': 1,
#          u'tired .+': 9,
#          u'talking .+': 6,
#          u'.+ got a': 6,
#          u'in .+ i': 2,
#          u'would .+': 26,
#          u'.+ talking': 6,
#          u'hit .+': 1,
#          u'i heard .+': 1,
#          u'.+ up': 54,
#          u'of .+ this': 3,
#          u'just .+ myself': 1,
#          u'is .+ a': 2,
#          u'the year .+': 2,
#          u'he .+': 25,
#          u'evil .+': 11,
#          u'in there .+': 2,
#          u'would you .+': 4,
#          u'.+ took': 3,
#          u'.+ all be': 1,
#          u'self .+': 1,
#          u'.+ why you': 3,
#          u'.+ is what': 7,
#          u'out .+': 39,
#          u'three .+': 34,
#          u'was .+ that': 1,
#          u'.+ and on': 1,
#          u'.+ weeks': 1,
#          u'.+ got to': 21,
#          u'and .+ do': 1,
#          u'.+ with it': 5,
#          u'like all .+': 1,
#          u'to me .+': 15,
#          u'.+ id': 2,
#          u'.+ anything': 9,
#          u'is so .+': 1,
#          u'someone you .+': 1,
#          u'.+ be like': 2,
#          u'.+ says': 4,
#          u'work at .+': 2,
#          u'.+ in': 108,
#          u'.+ it': 169,
#          u'.+ back in': 2,
#          u'.+ is': 143,
#          u'when i .+': 5,
#          u'.+ things in': 1,
#          u'you were .+': 1,
#          u'coffee .+': 1,
#          u'.+ idea': 7,
#          u'eye .+': 1,
#          u'.+ just': 89,
#          u'i stand .+': 1,
#          u'talking to .+': 3,
#          u'.+ your': 61,
#          u'.+ your own': 10,
#          u'.+ with this': 6,
#          u'.+ been': 28,
#          u'.+ you see': 4,
#          u'.+ a .+': 218,
#          u'me this .+': 2,
#          u'.+ piece of': 2,
#          u'.+ you could': 4,
#          u'to .+ for': 9,
#          u'me when .+': 1,
#          u'.+ you do': 8,
#          u'no .+ so': 3,
#          u'.+ funny': 7,
#          u'try to .+': 9,
#          u'little .+ and': 16,
#          u'.+ you not': 1,
#          u'you .+ them': 1,
#          u'small .+': 2,
#          u'.+ i hate': 34,
#          u'.+ talk to': 7,
#          u'you guys .+': 5,
#          u'.+ of that': 4,
#          u'i like .+': 7,
#          u'.+ like it': 7,
#          u'just .+ at': 1,
#          u'.+ go': 55,
#          u'.+ easily': 1,
#          u'.+ had a': 10,
#          u'why you .+': 3,
#          u'you the .+': 1,
#          u'just .+ the': 2,
#          u'many .+': 2,
#          u'is what .+': 7,
#          u'.+ sounds like': 1,
#          u'has never .+': 2,
#          u'like me .+': 1,
#          u'funny .+': 6,
#          u'you .+ it': 11,
#          u'.+ up the': 2,
#          u'.+ and then': 9,
#          u'goes .+': 5,
#          u'to you .+': 16,
#          u'.+ fucking .+': 2,
#          u'.+ for': 84,
#          u'.+ else': 8,
#          u'able to .+': 2,
#          u'.+ to wait': 1,
#          u'at this .+': 1,
#          u'is coming .+': 2,
#          u'.+ me off': 1,
#          u'but .+': 51,
#          u'and all .+': 2,
#          u'.+ .+ for': 84,
#          u'minute .+': 6,
#          u'.+ make me': 4,
#          u'.+ is a': 2,
#          u'am .+ you': 1,
#          u'.+ can': 37,
#          u'hear .+': 14,
#          u'have some .+': 7,
#          u'and .+ all': 1,
#          u'.+ how much': 1,
#          u'have no .+': 3,
#          u'find .+': 5,
#          u'.+ trying to': 1,
#          u'week to .+': 1,
#          u'.+ that .+': 128,
#          u'.+ thought': 9,
#          u'whoever .+': 1,
#          u'.+ is all': 1,
#          u'.+ to get': 11,
#          u'bill .+': 2,
#          u'and .+ what': 1,
#          u'better .+': 15,
#          u'a fucking .+': 1,
#          u'to have .+': 8,
#          u'the .+ thing': 1,
#          u'that .+ would': 1,
#          u'your .+ of': 1,
#          u'people have .+': 2,
#          u'and .+ this': 1,
#          u'start .+': 2,
#          u'we .+ to': 1,
#          u'you have .+': 27,
#          u'.+ laugh': 8,
#          u'.+ him and': 1,
#          u'me and .+': 2,
#          u'out the .+': 6,
#          u'.+ around': 10,
#          u'in the .+': 24,
#          u'times .+': 3,
#          u'time you .+': 2,
#          u'.+ call me': 1,
#          u'.+ bad': 1,
#          u'.+ i never': 19,
#          u'thing that .+': 1,
#          u'he never .+': 1,
#          u'sometimes .+': 8,
#          u'.+ how': 19,
#          u'so i .+': 1,
#          u'.+ i know': 8,
#          u'well .+': 55,
#          u'.+ you let': 6,
#          u'.+ done': 4,
#          u'up a .+': 2,
#          u'.+ seen': 2,
#          u'.+ seem': 3,
#          u'.+ to tell': 1,
#          u'just get .+': 2,
#          u'why .+': 55,
#          u'the day .+': 2,
#          u'.+ joe': 21,
#          u'you .+ someone': 1,
#          u'.+ los': 1,
#          u'.+ job': 9,
#          u'i said .+': 3,
#          u'.+ you should': 2,
#          u'full .+': 3,
#          u'just to .+': 3,
#          u'.+ to talk': 5,
#          u'into a .+': 3,
#          u'i .+ for': 4,
#          u'.+ come to': 5,
#          u'what .+ me': 7,
#          u'a total .+': 1,
#          u'.+ as if': 1,
#          u'what .+ my': 1,
#          u'.+ wrong': 5,
#          u'.+ line': 20,
#          u'well i .+': 6,
#          u'a .+ like': 1,
#          u'.+ nobody': 10,
#          u'the .+ here': 1,
#          u'.+ oh well': 1,
#          u'never .+ up': 2,
#          u'personal .+': 1,
#          u'.+ boy': 5,
#          u'that little .+': 1,
#          u'ice .+': 2,
#          u'who .+': 15,
#          u'sorry i .+': 1,
#          u'.+ freaking': 1,
#          u'.+ watch': 1,
#          u'fire .+': 1,
#          u'missing .+': 5,
#          u'.+ us': 5,
#          u'any .+': 22,
#          u'the .+ waiting': 4,
#          u'.+ more': 24,
#          u'look .+': 34,
#          u'care .+': 12,
#          u'.+ must': 17,
#          u'.+ to': 287,
#          u'this new .+': 1,
#          u'like i .+': 11,
#          u'can get .+': 4,
#          u'.+ heard': 1,
#          u'part .+': 1,
#          u'in .+ by': 1,
#          u'.+ in .+': 108,
#          u'worked .+': 3,
#          u'you .+ i': 19,
#          u'when they .+': 1,
#          u'.+ saving': 1,
#          u'.+ heart': 1,
#          u'you .+ a': 25,
#          u'they do .+': 1,
#          u'.+ if it': 4,
#          u'at all .+': 7,
#          u'or something .+': 3,
#          u'life .+': 11,
#          u'and it .+': 1,
#          u'what an .+': 1,
#          u'.+ dream': 3,
#          u'.+ roll': 7,
#          u'you .+ .+': 394,
#          u'you always .+': 13,
#          u'for .+ this': 1,
#          u'might .+': 6,
#          u'you .+ up': 2,
#          u'.+ through': 7,
#          u'time .+': 25,
#          u'.+ fast': 2,
#          u'i can .+': 12,
#          u'was .+ to': 1,
#          u'is .+ i': 7,
#          u'why .+ is': 1,
#          u'.+ find': 5,
#          u'.+ such a': 6,
#          u'.+ i would': 7,
#          u'i .+': 367,
#          ...})

# %%
10/2
# Out:
# 5
