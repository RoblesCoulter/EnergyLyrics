# %%
import pandas as pd
import os
import librosa
import numpy as np
import scipy
import re


#Data handling
from sklearn.model_selection import train_test_split

#Pickling
from six.moves import cPickle as pickle

#Metrics
from sklearn.metrics import recall_score, precision_score, f1_score

#HTTP
import requests
import json

#
import collections

import matplotlib.pyplot as plt
import matplotlib.style as ms
import librosa.display
import IPython.display as ipd
import seaborn
ms.use('seaborn-muted')
# %matplotlib inline

# %%
def get_pattern(text):
    text = json.dumps(text)
    url = 'http://192.168.2.101:7878/api/get_patt'
    data = dict(input_tweets = text)
    resp = requests.post(url=url, data=data)
    r = json.loads(resp.text)
    return map(lambda x: x['pattern'],r)
    
def get_deep_emotion(text):
    text = json.dumps(text)
    url = 'http://192.168.2.101:7878/api/get_emo'
    data = dict(input_tweets = text)
    resp = requests.post(url=url, data=data)
    r = json.loads(resp.text)
    return r

def clean_text(text, remove_actions = True):
    punct_str = '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~«»“…‘”'
    if(remove_actions):
        text = re.sub(r" ?\[[^)]+\]", "", text)
    for p in punct_str:
        text = text.replace(p,' ')
    text = re.sub(' +', ' ', text)
    return text.lower().strip()

def get_f1_score(precision,recall):
    return 2 * (precision * recall) / (precision + recall)

def get_patterns_load(data,patterns_df, emotion):
    index = data[data.emotion == emotion ]['index']
    patterns = patterns_df.loc[list(index)]
    load = []
    for pat in patterns.iterrows():
        load = load + list(pat[1].dropna())
    return load


def extract_patterns(data,extract=False):
    if(extract):
        patterns = {}
        for index, row in data.iterrows():
            patterns[row['index']] = set(get_pattern([row['text']])[0].values())
            print('Extracted pattern from '+ row['index'] + ' index:'+ str(index))
            print('Size: ', len(patterns[row['index']]), 'Patterns size', len(patterns))
        try:
            print('Saving Pickle')
            with open('pickles/patterns/pattern.pickle','wb') as f:
                save = {
                    'patterns' : patterns
                }
                pickle.dump(save,f,pickle.HIGHEST_PROTOCOL)
                print('Successfully saved in pattern.pickle')
                return patterns
        except Exception as e:
            print('Unable to save data to pickle', e)
            print('Patterns probably not saved.')
            return patterns
    else:
        try:
            with open('pickles/patterns/pattern.pickle','rb') as f:
                save = pickle.load(f)
                patterns = save['patterns']
                del save
                returning = {}
                for key in list(data['index']):
                    returning[key] = patterns[key]
                return returning
        except Exception as e:
            print('Error loading base datasets pickle: ', e)
            

def build_emotions_counter(data,patterns_df):
    emotions_counter ={}
    emotions_list = list(data['emotion'].unique())
    for emotion in emotions_list:
        load = get_patterns_load(data,patterns_df,emotion)
        emotions_counter[emotion] = collections.Counter(load)
    return emotions_counter

def build_frequencyframe(all_patterns,emotions_counter):
    df_patt = {}
    for pattern in all_patterns:
        df_patt[pattern] = {}
        for emotion in emotions_counter:
            df_patt[pattern][emotion] = emotions_counter[emotion][pattern]
    return pd.DataFrame(df_patt).T

def build_pfief(df_patt):
    ief = ((df_patt+1).rdiv(df_patt.sum(axis=1)+1, axis=0)+1).apply(np.log10)
    pf = ((df_patt.sum(axis=0)+1)/(df_patt+1)).apply(np.log10)
    return ief * pf

def balance_data(data):
    min_sample = min(data.groupby('emotion').count()['index'])
    emotions_list = list(data['emotion'].unique())
    samples = []
    for emotion in emotions_list:
        samples.append(data[data.emotion == emotion].sample(n=min_sample))
    result = pd.concat(samples).sample(frac=1)
    return result
        
def two_emotions(data,emotional_mapping,emotion1,emotion2):
    emotion_code = emotional_mapping[emotion1]
    emotion_sample = data[data.emotion_code == emotion_code]
    emotion_code2 = emotional_mapping[emotion2]
    emotion_sample2 = data[data.emotion_code == emotion_code2]
    if(len(emotion_sample2) < len(emotion_sample)):
        emotion_sample = emotion_sample.sample(n=len(emotion_sample2))
    else:
        emotion_sample2 = emotion_sample2.sample(n=len(emotion_sample))
    sample = pd.concat([emotion_sample,emotion_sample2]).sample(frac=1)
    return sample

def filter_word_count(data, n_count):
    return data[map(lambda x: len(x.split(' ')) >= n_count,data['text'])]

def remove_empty_patterns(data,patterns):
    empty_patterns = [k for k, v in patterns.iteritems() if len(v) < 1]
    patterns = { k:v for k, v in patterns.iteritems() if len(v) > 1 }
    data = filter(lambda x: x[1]['index'] not in empty_patterns ,data.iterrows())
    data = pd.DataFrame.from_items(data).T
    return data,patterns

# %%
# full = generate_IEMOCAP_df()
data = pd.read_csv('data/IEMOCAP_sentences.csv',index_col=0)

emotional_mapping = {'ang': 0, 'sad': 1, 'exc': 2, 'neu': 3,'fru': 4,'hap': 5,'fea': 6,'sur': 7,'dis': 8, 'xxx':9,'oth':10}
data['emotion_code'] = data['emotion'].map( emotional_mapping ).astype(int)

# Take away fear, surprise,disgust, xxx and others. Not enough data
data = data[data.emotion_code < 6]

# Clean Transcripts
data['text'] = data['text'].apply(clean_text)

# Filter Word Count
data = filter_word_count(data, 3)

patterns = extract_patterns(data) 
data,patterns = remove_empty_patterns(data,patterns)
data.groupby('emotion').count()['index']

# %%
# data = two_emotions(data,emotional_mapping,'neu','hap')
# Balance Data
data = balance_data(data)
y = data.emotion_code
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2)

# %%
print(len(X_train))
print(len(y_train))
print(len(X_test))
print(len(y_test))
# Out:
# 2491
# 2491
# 623
# 623

# %%
patterns = extract_patterns(X_train) 
# X_train,patterns = remove_empty_patterns(X_train,patterns)

patterns_df = pd.DataFrame.from_dict(patterns, orient='index')
emotions_counter = build_emotions_counter(X_train,patterns_df)
all_patterns = []
for pat in patterns_df.iterrows():
    all_patterns = all_patterns + list(pat[1].dropna())

# %%
df_patt = build_frequencyframe(all_patterns,emotions_counter)
em_df = build_pfief(df_patt)

# %%
df_patt.head(5)
# Out:
#            ang  exc  fru  hap  neu  sad
# .+ .+ a     81   84   77   70   70   76
# .+ .+ and  100   62   66   56   52   95
# .+ .+ for   34   30   52   29   24   32
# .+ .+ i    123  124  155  113   96  144
# .+ .+ if    28   11   27   13   14   10

# %%
em_df.head(5)
# Out:
#                 ang       exc       fru       hap       neu       sad
# .+ .+ a    1.869813  1.784834  1.952301  1.948413  1.943972  1.940252
# .+ .+ and  1.583129  2.098516  2.089434  2.172285  2.263011  1.633768
# .+ .+ for  2.202732  2.323134  1.704206  2.315040  2.567713  2.276720
# .+ .+ i    1.789243  1.735523  1.555995  1.788325  1.974476  1.608623
# .+ .+ if   1.808011  3.019062  1.868720  2.718888  2.610125  3.208357

# %% [markdown]
# # Score

# %%
trainpatterns = patterns
patterns_list = np.array(list(em_df.index))
frequency_vectors = []
for index in trainpatterns:
    frequency_vectors.append(np.isin(patterns_list,np.array(list(trainpatterns[index]))))
train_vectors = pd.DataFrame(frequency_vectors,columns=patterns_list,index=trainpatterns.keys())
train_vectors = train_vectors * 1

# %%
em_matrix = em_df.T.as_matrix()
emotional_scores = []
for index, vector in train_vectors.iterrows():
    emotional_scores.append(em_matrix.dot(vector))
emotions_list = list(em_df.columns)
scores = pd.DataFrame(emotional_scores,columns=emotions_list,index=trainpatterns.keys())
scores['pred_emotion'] = map(lambda x: x[1].idxmax(),scores.iterrows())
scores['pred_code'] = scores['pred_emotion'].map(emotional_mapping).astype(int)
# scores
pred_y = list(scores['pred_code'])

# %%
print(len(y_train))
print(len(pred_y))
# Out:
# 2491
# 2491

# %%
precision = precision_score(list(y_train),pred_y,average='macro')
recall = recall_score(list(y_train),pred_y,average='macro')
f1 = get_f1_score(precision,recall)
print('Precision Macro',precision)
print('Recall Macro',recall)
print('F1 Macro',f1)
print(' ')
precision = precision_score(list(y_train),pred_y,average='micro')
recall = recall_score(list(y_train),pred_y,average='micro')
f1 = get_f1_score(precision,recall)
print('Precision Micro',precision)
print('Recall Micro',recall)
print('F1 Micro',f1)
print(' ')
precision = precision_score(list(y_train),pred_y,average='weighted')
recall = recall_score(list(y_train),pred_y,average='weighted')
f1 = get_f1_score(precision,recall)
print('Precision Weighted',precision)
print('Recall Weighted',recall)
print('F1 Weighted',f1)
# Out:
# ('Precision Macro', 0.1636746849366546)
# ('Recall Macro', 0.1619048063983861)
# ('F1 Macro', 0.16278493506039735)
#
# ('Precision Micro', 0.1613809714973906)
# ('Recall Micro', 0.1613809714973906)
# ('F1 Micro', 0.1613809714973906)
#
# ('Precision Weighted', 0.1638268748752634)
# ('Recall Weighted', 0.1613809714973906)
# ('F1 Weighted', 0.16259472530964506)

# %% [markdown]
# #  Testing

# %%
testpatterns = extract_patterns(X_test)
# X_test,testpatterns = remove_empty_patterns(X_test,testpatterns)
patterns_list = np.array(list(em_df.index))
frequency_vectors = []
for index in testpatterns:
    frequency_vectors.append(np.isin(patterns_list,np.array(list(testpatterns[index]))))
test_vectors = pd.DataFrame(frequency_vectors,columns=patterns_list,index=testpatterns.keys())
test_vectors = test_vectors * 1

# %%
test_vectors.head(5)
# Out:
#                        .+ .+ a .+ .+ and .+ .+ for .+ .+ i .+ .+ if .+ .+ in  \
# Ses04M_impro06_F002          0         0         0       1        0        0
# Ses05M_impro07_F026          0         0         0       1        0        0
# Ses04F_script01_3_F009       0         0         0       1        0        0
# Ses03F_script01_3_F005       0         0         0       0        0        0
# Ses01M_script01_3_M019       0         0         0       0        0        0
#
#                        .+ .+ is .+ .+ me .+ .+ my .+ .+ of     ...      \
# Ses04M_impro06_F002           0        0        0        0     ...
# Ses05M_impro07_F026           0        0        0        0     ...
# Ses04F_script01_3_F009        1        0        0        0     ...
# Ses03F_script01_3_F005        0        1        0        0     ...
# Ses01M_script01_3_M019        0        0        0        0     ...
#
#                        your .+ while your .+ with your .+ you your .+ your  \
# Ses04M_impro06_F002                0            0           0            0
# Ses05M_impro07_F026                0            0           0            0
# Ses04F_script01_3_F009             0            0           0            0
# Ses03F_script01_3_F005             0            0           0            0
# Ses01M_script01_3_M019             0            0           0            0
#
#                        your eyes .+ your life .+ your name .+ your own .+  \
# Ses04M_impro06_F002               0            0            0           0
# Ses05M_impro07_F026               0            0            0           0
# Ses04F_script01_3_F009            0            0            0           0
# Ses03F_script01_3_F005            0            0            0           0
# Ses01M_script01_3_M019            0            0            0           0
#
#                        yours .+ yourself .+
# Ses04M_impro06_F002           0           0
# Ses05M_impro07_F026           0           0
# Ses04F_script01_3_F009        0           0
# Ses03F_script01_3_F005        0           0
# Ses01M_script01_3_M019        0           0
#
# [5 rows x 5534 columns]

# %%
em_matrix = em_df.T.as_matrix()
emotional_scores = []
for index, vector in test_vectors.iterrows():
    emotional_scores.append(em_matrix.dot(vector))

# %%
scores = pd.DataFrame(emotional_scores,columns=emotions_list,index=testpatterns.keys())
scores['pred_emotion'] = map(lambda x: x[1].idxmax(),scores.iterrows())
scores['pred_code'] = scores['pred_emotion'].map(emotional_mapping).astype(int)

# %%
pred_y = list(scores['pred_code'])

# %%
scores.head(5)
# Out:
#                                ang         exc        fru         hap  \
# Ses04M_impro06_F002      99.139289   89.965659  73.526430   84.657479
# Ses05M_impro07_F026     100.640608   65.732210  79.232180   64.317904
# Ses04F_script01_3_F009   63.751999   54.420359  54.272814   49.548197
# Ses03F_script01_3_F005  105.213510  114.618531  91.952336  116.690682
# Ses01M_script01_3_M019    7.033284    8.993313   7.439021    7.139038
#
#                                neu         sad pred_emotion  pred_code
# Ses04M_impro06_F002      84.969327   76.523179          ang          0
# Ses05M_impro07_F026      74.536743   73.048238          ang          0
# Ses04F_script01_3_F009   61.404683   62.270964          ang          0
# Ses03F_script01_3_F005  101.555030  104.836141          hap          5
# Ses01M_script01_3_M019    7.120810    7.330418          exc          2

# %%
print(len(y_test))
print(len(pred_y))
# Out:
# 623
# 623

# %%
precision = precision_score(list(y_test),pred_y,average='macro')
recall = recall_score(list(y_test),pred_y,average='macro')
f1 = get_f1_score(precision,recall)
print('Precision Macro',precision)
print('Recall Macro',recall)
print('F1 Macro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='micro')
recall = recall_score(list(y_test),pred_y,average='micro')
f1 = get_f1_score(precision,recall)
print('Precision Micro',precision)
print('Recall Micro',recall)
print('F1 Micro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='weighted')
recall = recall_score(list(y_test),pred_y,average='weighted')
f1 = get_f1_score(precision,recall)
print('Precision Weighted',precision)
print('Recall Weighted',recall)
print('F1 Weighted',f1)
# Out:
# ('Precision Macro', 0.15013141725320098)
# ('Recall Macro', 0.16084251151503925)
# ('F1 Macro', 0.15530249949868674)
#
# ('Precision Micro', 0.1653290529695024)
# ('Recall Micro', 0.1653290529695024)
# ('F1 Micro', 0.1653290529695024)
#
# ('Precision Weighted', 0.15215266819067705)
# ('Recall Weighted', 0.1653290529695024)
# ('F1 Weighted', 0.15846743205764563)

# %% [markdown]
# # Sad & Hap

# %%
precision = precision_score(list(y_test),pred_y,average='macro')
recall = recall_score(list(y_test),pred_y,average='macro')
f1 = get_f1_score(precision,recall)
print('Precision Macro',precision)
print('Recall Macro',recall)
print('F1 Macro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='micro')
recall = recall_score(list(y_test),pred_y,average='micro')
f1 = get_f1_score(precision,recall)
print('Precision Micro',precision)
print('Recall Micro',recall)
print('F1 Micro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='weighted')
recall = recall_score(list(y_test),pred_y,average='weighted')
f1 = get_f1_score(precision,recall)
print('Precision Weighted',precision)
print('Recall Weighted',recall)
print('F1 Weighted',f1)
# Out:
# ('Precision Macro', 0.5055895790803927)
# ('Recall Macro', 0.5053285145028265)
# ('F1 Macro', 0.5054590130822941)
#
# ('Precision Micro', 0.5)
# ('Recall Micro', 0.5)
# ('F1 Micro', 0.5)
#
# ('Precision Weighted', 0.5068047049674346)
# ('Recall Weighted', 0.5)
# ('F1 Weighted', 0.5033793569566477)

# %% [markdown]
# # Anger & Hap

# %%
precision = precision_score(list(y_test),pred_y,average='macro')
recall = recall_score(list(y_test),pred_y,average='macro')
f1 = get_f1_score(precision,recall)
print('Precision Macro',precision)
print('Recall Macro',recall)
print('F1 Macro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='micro')
recall = recall_score(list(y_test),pred_y,average='micro')
f1 = get_f1_score(precision,recall)
print('Precision Micro',precision)
print('Recall Micro',recall)
print('F1 Micro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='weighted')
recall = recall_score(list(y_test),pred_y,average='weighted')
f1 = get_f1_score(precision,recall)
print('Precision Weighted',precision)
print('Recall Weighted',recall)
print('F1 Weighted',f1)
# Out:
# ('Precision Macro', 0.546664167916042)
# ('Recall Macro', 0.546149569085349)
# ('F1 Macro', 0.5464067473400861)
#
# ('Precision Micro', 0.5432692307692307)
# ('Recall Micro', 0.5432692307692307)
# ('F1 Micro', 0.5432692307692307)
#
# ('Precision Weighted', 0.5480787250605467)
# ('Recall Weighted', 0.5432692307692307)
# ('F1 Weighted', 0.5456633803620117)

# %% [markdown]
# # Anger & Sadness

# %%
precision = precision_score(list(y_test),pred_y,average='macro')
recall = recall_score(list(y_test),pred_y,average='macro')
f1 = get_f1_score(precision,recall)
print('Precision Macro',precision)
print('Recall Macro',recall)
print('F1 Macro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='micro')
recall = recall_score(list(y_test),pred_y,average='micro')
f1 = get_f1_score(precision,recall)
print('Precision Micro',precision)
print('Recall Micro',recall)
print('F1 Micro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='weighted')
recall = recall_score(list(y_test),pred_y,average='weighted')
f1 = get_f1_score(precision,recall)
print('Precision Weighted',precision)
print('Recall Weighted',recall)
print('F1 Weighted',f1)
# Out:
# ('Precision Macro', 0.5026881720430108)
# ('Recall Macro', 0.5026881720430108)
# ('F1 Macro', 0.5026881720430108)
#
# ('Precision Micro', 0.5026737967914439)
# ('Recall Micro', 0.5026737967914439)
# ('F1 Micro', 0.5026737967914439)
#
# ('Precision Weighted', 0.5027025472945776)
# ('Recall Weighted', 0.5026737967914439)
# ('F1 Weighted', 0.5026881716319253)

# %% [markdown]
# # Neutral & Happiness

# %%
precision = precision_score(list(y_test),pred_y,average='macro')
recall = recall_score(list(y_test),pred_y,average='macro')
f1 = get_f1_score(precision,recall)
print('Precision Macro',precision)
print('Recall Macro',recall)
print('F1 Macro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='micro')
recall = recall_score(list(y_test),pred_y,average='micro')
f1 = get_f1_score(precision,recall)
print('Precision Micro',precision)
print('Recall Micro',recall)
print('F1 Micro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='weighted')
recall = recall_score(list(y_test),pred_y,average='weighted')
f1 = get_f1_score(precision,recall)
print('Precision Weighted',precision)
print('Recall Weighted',recall)
print('F1 Weighted',f1)
# Out:
# ('Precision Macro', 0.5026881720430108)
# ('Recall Macro', 0.5026881720430108)
# ('F1 Macro', 0.5026881720430108)
#
# ('Precision Micro', 0.5026737967914439)
# ('Recall Micro', 0.5026737967914439)
# ('F1 Micro', 0.5026737967914439)
#
# ('Precision Weighted', 0.5027025472945776)
# ('Recall Weighted', 0.5026737967914439)
# ('F1 Weighted', 0.5026881716319253)

# %% [markdown]
# # Neutral & Sadness

# %%
precision = precision_score(list(y_test),pred_y,average='macro')
recall = recall_score(list(y_test),pred_y,average='macro')
f1 = get_f1_score(precision,recall)
print('Precision Macro',precision)
print('Recall Macro',recall)
print('F1 Macro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='micro')
recall = recall_score(list(y_test),pred_y,average='micro')
f1 = get_f1_score(precision,recall)
print('Precision Micro',precision)
print('Recall Micro',recall)
print('F1 Micro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='weighted')
recall = recall_score(list(y_test),pred_y,average='weighted')
f1 = get_f1_score(precision,recall)
print('Precision Weighted',precision)
print('Recall Weighted',recall)
print('F1 Weighted',f1)
# Out:
# ('Precision Macro', 0.47599318351262115)
# ('Recall Macro', 0.4760416666666667)
# ('F1 Macro', 0.47601742385512175)
#
# ('Precision Micro', 0.4769585253456221)
# ('Recall Micro', 0.4769585253456221)
# ('F1 Micro', 0.4769585253456221)
#
# ('Precision Weighted', 0.4765562995818717)
# ('Recall Weighted', 0.4769585253456221)
# ('F1 Weighted', 0.4767573276273286)

# %% [markdown]
# # Neutral & Anger

# %%
precision = precision_score(list(y_test),pred_y,average='macro')
recall = recall_score(list(y_test),pred_y,average='macro')
f1 = get_f1_score(precision,recall)
print('Precision Macro',precision)
print('Recall Macro',recall)
print('F1 Macro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='micro')
recall = recall_score(list(y_test),pred_y,average='micro')
f1 = get_f1_score(precision,recall)
print('Precision Micro',precision)
print('Recall Micro',recall)
print('F1 Micro',f1)
print(' ')
precision = precision_score(list(y_test),pred_y,average='weighted')
recall = recall_score(list(y_test),pred_y,average='weighted')
f1 = get_f1_score(precision,recall)
print('Precision Weighted',precision)
print('Recall Weighted',recall)
print('F1 Weighted',f1)
# Out:
# ('Precision Macro', 0.46908434525763043)
# ('Recall Macro', 0.4709975369458128)
# ('F1 Macro', 0.4700389943019242)
#
# ('Precision Micro', 0.47737556561085975)
# ('Recall Micro', 0.47737556561085975)
# ('F1 Micro', 0.47737556561085975)
#
# ('Precision Weighted', 0.47071297782701477)
# ('Recall Weighted', 0.47737556561085975)
# ('F1 Weighted', 0.4740208614181354)

# %%
# TODO
#Word count higher than 3
#Filter out empty patterns

# %%
data['text']
# Out:
# 5977      what who says that bananas don't grow overnight
# 8253    what do you mean as you can who makes up these...
# 6006           well i guess you're not trying hard enough
# 4582                 oh very amusing indeed amanda listen
# 1622                                             what huh
# 9810          twice is every time we've tried that's ever
# 1978    dumber than you i mean they're a lot worse off...
# 1339                     i'm going to ask her to marry me
# 5837                      that's how you want to leave it
# 5955    well i can't be in charge of this i mean i got...
# 2653                           stop it go away i hate you
# 4928                          what is the matter with you
# 573                                           whose is it
# 1814                           that's very amusing indeed
# 1993    no it didn't um it didn't come out and i don't...
# 4966                                          yes sir yes
# 5775    okay what is it that i did wrong on the form t...
# 8214                         so what's the something else
# 1807    would you uh turn that off please you're going...
# 9268                               it's a biohazard so um
# 3894                                        how you doing
# 252     right now all i can do is just give you this f...
# 6415    i've given it three years of thought i hoped t...
# 4819                well i'm moving up i mean it could be
# 6818                                                 stop
# 4008                            is what's going to happen
# 6622    for heaven's sake grow up we are not going to ...
# 2252    for god sakes it's been three years nobody com...
# 1774    oh yes i am oh yes i am let go of me you let g...
# 6820            this is the end do you understand the end
#                               ...
# 2184    you know the kids wanna go to the beach and st...
# 1171                                                mmhmm
# 9451                         this happens every two weeks
# 1623                        you want to get married again
# 6191                                        hey what's up
# 421     i'll get out i'll get married and i'll move so...
# 3093    pretend like your on a rotary phone goes strai...
# 6802    i don't care okay do you understand i don't ca...
# 1843                                                   hi
# 4130                                         it just is i
# 7735         meaning that sacred and beautiful thing love
# 9539      you infuriate me sometimes do you know that god
# 4959    i mean our airline's fault i don't know what h...
# 1940                                    that's great yeah
# 4583                                  very amusing indeed
# 847     that's very interesting amanda how about a chi...
# 4538    stop it stop it i hate you i loath you you are...
# 8297                   well my hands are really tied then
# 2702                           you're not going like this
# 5587                                            yes it is
# 3852                 up to a limit of twenty five dollars
# 5309                      the business doesn't inspire me
# 5760                                  very amusing indeed
# 6322         you're going to fill out a form on your desk
# 4571    you had a riotous must have had a riotous time...
# 3995    okay well we will send you we will reimburse y...
# 6054    you have to make amends for what you did for l...
# 9273    uh like an hour and a half ago i talked to som...
# 8481                                   six four nine four
# 6350    to you it is and to me but not to him you can ...
# Name: text, Length: 2206, dtype: object

# %%
patterns_df
# Out:
#                                   0              1                2    \
# Ses01F_script02_2_F041         the .+          we .+        the .+ .+
# Ses05F_script01_1_M013         .+ mom       .+ years           for .+
# Ses05F_script03_2_M041       .+ music        very .+        .+ indeed
# Ses04F_impro07_M076         you .+ to         you .+        .+ .+ you
# Ses04F_impro07_M077         .+ .+ you      .+ campus        .+ do you
# Ses05F_script03_2_F041           None           None             None
# Ses04F_impro07_M071            the .+      .+ the .+        the .+ .+
# Ses04F_impro07_M072             of .+       .+ of .+          .+ boys
# Ses03F_impro08_M021          about .+       three .+       .+ dollars
# Ses01M_script01_1_M000          .+ it         .+ saw         he .+ it
# Ses01M_script01_1_M002         the .+     i heard .+          .+ here
# Ses03F_impro02_F000          going .+        .+ babe         .+ it .+
# Ses03F_impro02_F001              None           None             None
# Ses02F_script03_2_M011   they were .+        were .+          .+ ones
# Ses02M_script02_1_F000           None           None             None
# Ses05M_impro05_F021             .+ on       .+ .+ on          okay .+
# Ses04F_script01_1_F041         the .+         you .+        .+ .+ you
# Ses04F_script01_1_F040       think .+        .+ that       alright .+
# Ses02F_script01_1_F027         the .+    the same .+        .+ .+ you
# Ses04F_script01_1_F042         you .+       think .+        .+ .+ you
# Ses04F_script01_1_F044      yeah i .+         .+ see         i .+ see
# Ses05F_script01_3_F024         you .+       still .+          like .+
# Ses02F_script03_1_M026         the .+         you .+        .+ .+ you
# Ses02F_script03_1_M024         the .+      .+ .+ you         green .+
# Ses02F_script03_1_M025         you .+    .+ remember         awful .+
# Ses02F_script03_1_M021         the .+          .+ is        the .+ .+
# Ses05F_impro05_F007            you .+      .+ .+ you         .+ leave
# Ses05F_impro05_F006           .+ good           None             None
# Ses05F_impro05_F005              None           None             None
# Ses02F_script03_1_M028        .+ that         .+ did           how .+
# ...                               ...            ...              ...
# Ses04M_script03_2_M049           .+ a           a .+          a .+ .+
# Ses01F_script01_2_M008     how .+ you         you .+        .+ .+ you
# Ses01F_script01_2_M001        .+ just      wanted .+        to see .+
# Ses01M_script02_2_M013        .+ them        them .+         .+ twice
# Ses02F_impro08_F025             we .+      yeah i .+          easy .+
# Ses02F_script03_1_F012        .+ they           None             None
# Ses02F_impro08_F026            you .+      .+ .+ you      to .+ again
# Ses03M_script01_1_M037        .+ here          .+ if          .+ that
# Ses05F_impro06_M012             to .+          .+ he         .+ close
# Ses05F_impro06_M017          .+ there          .+ or          is .+ a
# Ses05F_impro06_M019        .+ problem          no .+             None
# Ses03M_script01_1_M039        been .+          .+ it           and .+
# Ses03M_script01_1_M038         .+ new        .+ else           her .+
# Ses04M_script03_1_F013          .+ at       .+ laugh            if .+
# Ses03F_script02_1_M019           None           None             None
# Ses04M_impro04_F000         .+ .+ you      has to .+         be .+ .+
# Ses04M_impro04_F001          about .+        what .+          .+ .+ a
# Ses04M_impro04_F004         you .+ to      .+ .+ you         i .+ you
# Ses04M_impro04_F005            .+ bad     .+ to take         .+ field
# Ses04M_impro04_F006           .+ then       to be .+         .+ .+ to
# Ses04F_script01_1_M038         the .+      .+ the .+         .+ .+ me
# Ses04F_script01_1_M034          .+ if        .+ that        i .+ that
# Ses04F_script01_1_M030  because .+ is  because it .+         .+ it is
# Ses04M_impro08_M027            the .+         you .+        .+ .+ you
# Ses04M_impro08_M026           .+ .+ i      .+ .+ you            .+ if
# Ses04M_impro08_M025         you .+ to      .+ .+ you            co .+
# Ses04F_script01_2_F010       knows .+       .+ knows            .+ as
# Ses04F_script01_2_F016     look at .+        goes .+            .+ at
# Ses04M_impro08_M021              None           None             None
# Ses04M_impro08_M020       .+ but like        .+ like  really .+ about
#
#                                     3             4                 5    \
# Ses01F_script02_2_F041         right .+      .+ wrong         .+ but .+
# Ses05F_script01_1_M013          .+ back      .+ comes           back .+
# Ses05F_script03_2_M041         music .+          None              None
# Ses04F_impro07_M076           .+ for it     .+ but .+             .+ it
# Ses04F_impro07_M077             .+ live       .+ year             .+ on
# Ses05F_script03_2_F041             None          None              None
# Ses04F_impro07_M071             .+ want      thing .+        want to .+
# Ses04F_impro07_M072               .+ of      drunk .+        lots of .+
# Ses03F_impro08_M021            .+ three          None              None
# Ses01M_script01_1_M000           saw .+         he .+              None
# Ses01M_script01_1_M002  .+ this morning     .+ out .+            was .+
# Ses03F_impro02_F000               .+ it         it .+          .+ going
# Ses03F_impro02_F001                None          None              None
# Ses02F_script03_2_M011          they .+       very .+             no .+
# Ses02M_script02_1_F000             None          None              None
# Ses05M_impro05_F021                None          None              None
# Ses04F_script01_1_F041            we .+       .+ just       .+ shooting
# Ses04F_script01_1_F040       .+ that .+        .+ way         .+ but .+
# Ses02F_script01_1_F027        .+ do you        how .+         the .+ .+
# Ses04F_script01_1_F042         .+ .+ me   that .+ you        .+ .+ that
# Ses04F_script01_1_F044         i can .+   can .+ that           .+ i .+
# Ses05F_script01_3_F024     .+ like that  .+ feel like           feel .+
# Ses02F_script03_1_M026         it .+ my       .+ that         the .+ .+
# Ses02F_script03_1_M024         .+ dance         .+ me             .+ do
# Ses02F_script03_1_M025       .+ that .+        .+ had          we .+ in
# Ses02F_script03_1_M021            .+ in         so .+  .+ everyone else
# Ses05F_impro05_F007               .+ it          i .+          .+ could
# Ses05F_impro05_F006                None          None              None
# Ses05F_impro05_F005                None          None              None
# Ses02F_script03_1_M028          .+ long    .+ that .+        .+ .+ that
# ...                                 ...           ...               ...
# Ses04M_script03_2_M049        .+ living       .+ a .+              None
# Ses01F_script01_2_M008            do .+     .+ do you            .+ why
# Ses01F_script01_2_M001            .+ to       well .+         .+ to see
# Ses01M_script02_2_M013       .+ them .+     missed .+             we .+
# Ses02F_impro08_F025       .+ completely         .+ as        want to .+
# Ses02F_script03_1_F012             None          None              None
# Ses02F_impro08_F026               we .+       .+ that      thank you .+
# Ses03M_script01_1_M037            if .+          i .+            get .+
# Ses05F_impro06_M012              was .+        his .+          .+ .+ to
# Ses05F_impro06_M017             .+ .+ a       a .+ .+        there a .+
# Ses05F_impro06_M019                None          None              None
# Ses03M_script01_1_M039             a .+        .+ and            .+ too
# Ses03M_script01_1_M038         maybe .+        .+ her            new .+
# Ses04M_script03_1_F013        .+ i must       .+ must            .+ too
# Ses03F_script02_1_M019             None          None              None
# Ses04M_impro04_F000              has .+         .+ to           well .+
# Ses04M_impro04_F001                .+ a       a .+ .+     what about .+
# Ses04M_impro04_F004     really .+ about      be .+ .+        have to .+
# Ses04M_impro04_F005           .+ .+ you          a .+            .+ fit
# Ses04M_impro04_F006               .+ be         to .+        .+ then .+
# Ses04F_script01_1_M038       the .+ the     the .+ .+             .+ me
# Ses04F_script01_1_M034            if .+        .+ dad             .+ it
# Ses04F_script01_1_M030         .+ it .+      .+ .+ is             .+ it
# Ses04M_impro08_M027           .+ up the         so .+           .+ just
# Ses04M_impro08_M026             .+ like      whole .+             if .+
# Ses04M_impro08_M025           .+ do you      .+ where       actually .+
# Ses04F_script01_2_F010             i .+        she .+         .+ i know
# Ses04F_script01_2_F016         to .+ in         .+ in             .+ it
# Ses04M_impro08_M021                None          None              None
# Ses04M_impro08_M020             .+ here     .+ but .+              i .+
#
#                                 6             7            8    \
# Ses01F_script02_2_F041    .+ but we  .+ the right       .+ but
# Ses05F_script01_1_M013     .+ after   .+ after .+     three .+
# Ses05F_script03_2_M041         None          None         None
# Ses04F_impro07_M076            i .+       .+ yeah   .+ have .+
# Ses04F_impro07_M077     .+ going to      .+ going        .+ to
# Ses05F_script03_2_F041         None          None         None
# Ses04F_impro07_M071          and .+        get .+        .+ to
# Ses04F_impro07_M072            None          None         None
# Ses03F_impro08_M021            None          None         None
# Ses01M_script01_1_M000         None          None         None
# Ses01M_script01_1_M002        .+ at     the .+ .+     right .+
# Ses03F_impro02_F000            None          None         None
# Ses03F_impro02_F001            None          None         None
# Ses02F_script03_2_M011    reason .+      small .+    .+ reason
# Ses02M_script02_1_F000         None          None         None
# Ses05M_impro05_F021            None          None         None
# Ses04F_script01_1_F041    the .+ .+       hell .+     whole .+
# Ses04F_script01_1_F040      that .+        .+ but   .+ .+ that
# Ses02F_script01_1_F027      .+ your    she .+ the       .+ how
# Ses04F_script01_1_F042        .+ me     you .+ .+   .+ that .+
# Ses04F_script01_1_F044      .+ that        see .+   .+ .+ that
# Ses05F_script01_3_F024   .+ .+ that       .+ that       .+ you
# Ses02F_script03_1_M026   .+ and put        .+ bed        .+ my
# Ses02F_script03_1_M024       and .+      .+ and i         a .+
# Ses02F_script03_1_M025   .+ .+ that     you .+ .+        .+ in
# Ses02F_script03_1_M021      else .+       long .+     .+ in .+
# Ses05F_impro05_F007        leave .+       well .+      find .+
# Ses05F_impro05_F006            None          None         None
# Ses05F_impro05_F005            None          None         None
# Ses02F_script03_1_M028      long .+       that .+      .+ last
# ...                             ...           ...          ...
# Ses04M_script03_2_M049         None          None         None
# Ses01F_script01_2_M008    you .+ .+   know why .+        .+ do
# Ses01F_script01_2_M001     maybe .+        .+ her       see .+
# Ses01M_script02_2_M013    .+ missed          None         None
# Ses02F_impro08_F025          and .+  sometimes .+         a .+
# Ses02F_script03_1_F012         None          None         None
# Ses02F_impro08_F026      for .+ and    .+ will .+      much .+
# Ses03M_script01_1_M037   .+ have .+        but .+   here .+ .+
# Ses05F_impro06_M012         very .+        .+ his    to his .+
# Ses05F_impro06_M017            .+ a   is there .+     there .+
# Ses05F_impro06_M019            None          None         None
# Ses03M_script01_1_M039    .+ and .+          .+ a      with .+
# Ses03M_script01_1_M038      else .+  .+ somewhere    .+ get .+
# Ses04M_script03_1_F013         .+ i       at .+ i        us .+
# Ses03F_script02_1_M019         None          None         None
# Ses04M_impro04_F000           .+ be      .+ there       .+ has
# Ses04M_impro04_F001       like a .+    .+ like .+      .+ a .+
# Ses04M_impro04_F004     .+ you have          i .+  .+ about .+
# Ses04M_impro04_F005          new .+      gonna .+    really .+
# Ses04M_impro04_F006       .+ really      be .+ .+        .+ to
# Ses04F_script01_1_M038  business .+   .+ business       .+ the
# Ses04F_script01_1_M034         i .+   .+ about .+    forget .+
# Ses04F_script01_1_M030        it .+         .+ is   because .+
# Ses04M_impro08_M027       the .+ .+      be .+ .+      ever .+
# Ses04M_impro08_M026       .+ but .+          i .+    .+ but no
# Ses04M_impro08_M025        oh .+ .+     i .+ know        no .+
# Ses04F_script01_2_F010         a .+          .+ i         .+ a
# Ses04F_script01_2_F016       and .+        she .+      room .+
# Ses04M_impro08_M021            None          None         None
# Ses04M_impro08_M020       nobody .+   .+ about .+      like .+
#
#                                     9    ...    195   196   197   198   199  \
# Ses01F_script02_2_F041            so .+  ...   None  None  None  None  None
# Ses05F_script01_1_M013        nobody .+  ...   None  None  None  None  None
# Ses05F_script03_2_M041             None  ...   None  None  None  None  None
# Ses04F_impro07_M076              .+ but  ...   None  None  None  None  None
# Ses04F_impro07_M077             well .+  ...   None  None  None  None  None
# Ses05F_script03_2_F041             None  ...   None  None  None  None  None
# Ses04F_impro07_M071              .+ and  ...   None  None  None  None  None
# Ses04F_impro07_M072                None  ...   None  None  None  None  None
# Ses03F_impro08_M021                None  ...   None  None  None  None  None
# Ses01M_script01_1_M000             None  ...   None  None  None  None  None
# Ses01M_script01_1_M002          .+ over  ...   None  None  None  None  None
# Ses03F_impro02_F000                None  ...   None  None  None  None  None
# Ses03F_impro02_F001                None  ...   None  None  None  None  None
# Ses02F_script03_2_M011          .+ were  ...   None  None  None  None  None
# Ses02M_script02_1_F000             None  ...   None  None  None  None  None
# Ses05M_impro05_F021                None  ...   None  None  None  None  None
# Ses04F_script01_1_F041      the hell .+  ...   None  None  None  None  None
# Ses04F_script01_1_F040           but .+  ...   None  None  None  None  None
# Ses02F_script01_1_F027          well .+  ...   None  None  None  None  None
# Ses04F_script01_1_F042          .+ hear  ...   None  None  None  None  None
# Ses04F_script01_1_F044          yeah .+  ...   None  None  None  None  None
# Ses05F_script01_3_F024         .+ still  ...   None  None  None  None  None
# Ses02F_script03_1_M026            .+ it  ...   None  None  None  None  None
# Ses02F_script03_1_M024          word .+  ...   None  None  None  None  None
# Ses02F_script03_1_M025          .+ that  ...   None  None  None  None  None
# Ses02F_script03_1_M021        in the .+  ...   None  None  None  None  None
# Ses05F_impro05_F007                .+ i  ...   None  None  None  None  None
# Ses05F_impro05_F006                None  ...   None  None  None  None  None
# Ses05F_impro05_F005                None  ...   None  None  None  None  None
# Ses02F_script03_1_M028           did .+  ...   None  None  None  None  None
# ...                                 ...  ...    ...   ...   ...   ...   ...
# Ses04M_script03_2_M049             None  ...   None  None  None  None  None
# Ses01F_script01_2_M008           .+ you  ...   None  None  None  None  None
# Ses01F_script01_2_M001       .+ he just  ...   None  None  None  None  None
# Ses01M_script02_2_M013             None  ...   None  None  None  None  None
# Ses02F_impro08_F025               .+ to  ...   None  None  None  None  None
# Ses02F_script03_1_F012             None  ...   None  None  None  None  None
# Ses02F_impro08_F026        .+ will come  ...   None  None  None  None  None
# Ses03M_script01_1_M037             .+ i  ...   None  None  None  None  None
# Ses05F_impro06_M012               he .+  ...   None  None  None  None  None
# Ses05F_impro06_M017                a .+  ...   None  None  None  None  None
# Ses05F_impro06_M019                None  ...   None  None  None  None  None
# Ses03M_script01_1_M039          long .+  ...   None  None  None  None  None
# Ses03M_script01_1_M038     somewhere .+  ...   None  None  None  None  None
# Ses04M_script03_1_F013  .+ everything i  ...   None  None  None  None  None
# Ses03F_script02_1_M019             None  ...   None  None  None  None  None
# Ses04M_impro04_F000            to .+ .+  ...   None  None  None  None  None
# Ses04M_impro04_F001           .+ like a  ...   None  None  None  None  None
# Ses04M_impro04_F004               .+ to  ...   None  None  None  None  None
# Ses04M_impro04_F005            .+ a new  ...   None  None  None  None  None
# Ses04M_impro04_F006               be .+  ...   None  None  None  None  None
# Ses04F_script01_1_M038             None  ...   None  None  None  None  None
# Ses04F_script01_1_M034         years .+  ...   None  None  None  None  None
# Ses04F_script01_1_M030             None  ...   None  None  None  None  None
# Ses04M_impro08_M027         you ever .+  ...   None  None  None  None  None
# Ses04M_impro08_M026            .+ whole  ...   None  None  None  None  None
# Ses04M_impro08_M025              see .+  ...   None  None  None  None  None
# Ses04F_script01_2_F010           why .+  ...   None  None  None  None  None
# Ses04F_script01_2_F016          look .+  ...   None  None  None  None  None
# Ses04M_impro08_M021                None  ...   None  None  None  None  None
# Ses04M_impro08_M020       care about .+  ...   None  None  None  None  None
#
#                          200   201   202   203   204
# Ses01F_script02_2_F041  None  None  None  None  None
# Ses05F_script01_1_M013  None  None  None  None  None
# Ses05F_script03_2_M041  None  None  None  None  None
# Ses04F_impro07_M076     None  None  None  None  None
# Ses04F_impro07_M077     None  None  None  None  None
# Ses05F_script03_2_F041  None  None  None  None  None
# Ses04F_impro07_M071     None  None  None  None  None
# Ses04F_impro07_M072     None  None  None  None  None
# Ses03F_impro08_M021     None  None  None  None  None
# Ses01M_script01_1_M000  None  None  None  None  None
# Ses01M_script01_1_M002  None  None  None  None  None
# Ses03F_impro02_F000     None  None  None  None  None
# Ses03F_impro02_F001     None  None  None  None  None
# Ses02F_script03_2_M011  None  None  None  None  None
# Ses02M_script02_1_F000  None  None  None  None  None
# Ses05M_impro05_F021     None  None  None  None  None
# Ses04F_script01_1_F041  None  None  None  None  None
# Ses04F_script01_1_F040  None  None  None  None  None
# Ses02F_script01_1_F027  None  None  None  None  None
# Ses04F_script01_1_F042  None  None  None  None  None
# Ses04F_script01_1_F044  None  None  None  None  None
# Ses05F_script01_3_F024  None  None  None  None  None
# Ses02F_script03_1_M026  None  None  None  None  None
# Ses02F_script03_1_M024  None  None  None  None  None
# Ses02F_script03_1_M025  None  None  None  None  None
# Ses02F_script03_1_M021  None  None  None  None  None
# Ses05F_impro05_F007     None  None  None  None  None
# Ses05F_impro05_F006     None  None  None  None  None
# Ses05F_impro05_F005     None  None  None  None  None
# Ses02F_script03_1_M028  None  None  None  None  None
# ...                      ...   ...   ...   ...   ...
# Ses04M_script03_2_M049  None  None  None  None  None
# Ses01F_script01_2_M008  None  None  None  None  None
# Ses01F_script01_2_M001  None  None  None  None  None
# Ses01M_script02_2_M013  None  None  None  None  None
# Ses02F_impro08_F025     None  None  None  None  None
# Ses02F_script03_1_F012  None  None  None  None  None
# Ses02F_impro08_F026     None  None  None  None  None
# Ses03M_script01_1_M037  None  None  None  None  None
# Ses05F_impro06_M012     None  None  None  None  None
# Ses05F_impro06_M017     None  None  None  None  None
# Ses05F_impro06_M019     None  None  None  None  None
# Ses03M_script01_1_M039  None  None  None  None  None
# Ses03M_script01_1_M038  None  None  None  None  None
# Ses04M_script03_1_F013  None  None  None  None  None
# Ses03F_script02_1_M019  None  None  None  None  None
# Ses04M_impro04_F000     None  None  None  None  None
# Ses04M_impro04_F001     None  None  None  None  None
# Ses04M_impro04_F004     None  None  None  None  None
# Ses04M_impro04_F005     None  None  None  None  None
# Ses04M_impro04_F006     None  None  None  None  None
# Ses04F_script01_1_M038  None  None  None  None  None
# Ses04F_script01_1_M034  None  None  None  None  None
# Ses04F_script01_1_M030  None  None  None  None  None
# Ses04M_impro08_M027     None  None  None  None  None
# Ses04M_impro08_M026     None  None  None  None  None
# Ses04M_impro08_M025     None  None  None  None  None
# Ses04F_script01_2_F010  None  None  None  None  None
# Ses04F_script01_2_F016  None  None  None  None  None
# Ses04M_impro08_M021     None  None  None  None  None
# Ses04M_impro08_M020     None  None  None  None  None
#
# [1764 rows x 205 columns]
