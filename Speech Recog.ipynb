# %%
import tflearn
import librosa
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
learning_rate = 0.0001
training_iters = 300000

batch
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-3-8bb98e2f190e> in <module>()
#       2 training_iters = 300000
#       3
# ----> 4 batch
#
# NameError: name 'batch' is not defined

# %%
dev_path = 'cv-valid-dev'
train_path = 'common-voice/cv-valid-train'
test_path = 'common-voice/cv-valid-test'
dev_files = os.listdir('common-voice/'+dev_path)
dev_files = list(map(lambda x: dev_path +'/'+ x,dev_files))

# %%
dev_data = pd.read_csv('common-voice/cv-valid-dev.csv',index_col=0)
batch_features = []
labels = []
for mp3 in dev_files:
    wave, sr = librosa.load('common-voice/' + mp3, mono=True)
    mfcc = librosa.feature.mfcc(wave,sr)
    mfcc=np.pad(mfcc,((0,0),(0,1000-len(mfcc[0]))), mode='constant', constant_values=0)
    batch_features.append(np.array(mfcc))
    labels.append(dev_data[dev_data.filename == mp3])
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# <ipython-input-88-3597261e7169> in <module>()
#       5     wave, sr = librosa.load('common-voice/' + mp3, mono=True)
#       6     mfcc = librosa.feature.mfcc(wave,sr)
# ----> 7     mfcc=np.pad(mfcc,((0,0),(0,1000-len(mfcc[0]))), mode='constant', constant_values=0)
#       8     batch_features.append(np.array(mfcc))
#       9     labels.append(dev_data[dev_data.filename == mp3])
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/numpy/lib/arraypad.py in pad(array, pad_width, mode, **kwargs)
#    1293
#    1294     narray = np.array(array)
# -> 1295     pad_width = _validate_lengths(narray, pad_width)
#    1296
#    1297     allowedkwargs = {
#
# /Users/roblescoulter/anaconda/lib/python3.5/site-packages/numpy/lib/arraypad.py in _validate_lengths(narray, number_elements)
#    1084         if (chk[0] < 0) or (chk[1] < 0):
# ...

# %%
friends_dev = pd.read_json('EmotionLines/Friends/friends_dev.json')

# %%
friends_dev
# Out:
#                                                    0   \
# 0   {'emotion': 'non-neutral', 'utterance': 'Oh my...
# 1   {'emotion': 'neutral', 'utterance': 'Hey Estel...
# 2   {'emotion': 'neutral', 'utterance': 'Yes? Yes?...
# 3   {'emotion': 'anger', 'utterance': 'You had no ...
# 4   {'emotion': 'joy', 'utterance': 'Oh, it's so r...
# 5   {'emotion': 'neutral', 'utterance': 'Hey! What...
# 6   {'emotion': 'neutral', 'utterance': 'Hey, what...
# 7   {'emotion': 'neutral', 'utterance': 'So where ...
# 8   {'emotion': 'neutral', 'utterance': 'Well, you...
# 9   {'emotion': 'neutral', 'utterance': 'Okay. You...
# 10  {'emotion': 'joy', 'utterance': 'Hey Toby!', '...
# 11  {'emotion': 'neutral', 'utterance': 'Well, I w...
# 12  {'emotion': 'anger', 'utterance': 'Why isnt t...
# 13  {'emotion': 'neutral', 'utterance': 'Phoebe!',...
# 14  {'emotion': 'neutral', 'utterance': 'Come on, ...
# 15  {'emotion': 'neutral', 'utterance': 'Okay, it'...
# ...

# %%
dev_data[dev_data.filename == dev_files[1]]
# Out:
#                             filename  \
# 1897  cv-valid-dev/sample-001897.mp3
#
#                                                 text  up_votes  down_votes  \
# 1897  there wasn't much impetus to finish our chores         2           0
#
#       age gender accent  duration                  energy_score  text_len  \
# 1897  NaN    NaN    NaN       NaN  [34 15 89 19  4 12  5 11  8]         8
#
#      ambiguous             emotion
# 1897       yes  ['joy', 'sadness']
